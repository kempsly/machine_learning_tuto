# %% [markdown]
# INtroduction to Umap-learn python library

# %% [markdown]
# **`map-learn`** is a Python library designed to facilitate **dimensionality reduction** techniques for **manifold learning**. It extends **Scikit-learn** by providing advanced visualization and manifold-learning algorithms, making it easier to analyze and understand high-dimensional data by projecting it into lower-dimensional spaces.
#
# ---
#
# ### **Key Features of `map-learn`:**
# 1. **Manifold Learning:** Tools to explore non-linear relationships in data.
# 2. **Visualization:** Create visual representations of high-dimensional data in 2D or 3D.
# 3. **Extensibility:** Works seamlessly with Scikit-learn and its pipeline system.
# 4. **Ease of Use:** Intuitive API for applying manifold-learning techniques.
#
# ---
#
# ### **Installation:**
# To install `map-learn`, use the following command:
# ```bash
# pip install map-learn
# ```
#
# ---
#
# ### **Common Use Cases:**
# 1. **Visualizing High-Dimensional Data:**
#    - Reduce data dimensions for visualization purposes (e.g., t-SNE, UMAP).
# 2. **Clustering Analysis:**
#    - Understand clusters in high-dimensional spaces.
# 3. **Feature Engineering:**
#    - Generate features using non-linear manifold learning.
#
# ---
#
#
# ### **Key Dimensionality Reduction Techniques in `map-learn`:**
# 1. **t-SNE (t-distributed Stochastic Neighbor Embedding):**
#    - Good for cluster visualization.
# 2. **UMAP (Uniform Manifold Approximation and Projection):**
#    - Excellent for both visualization and preserving data structure.
# 3. **Laplacian Eigenmaps:**
#    - Graph-based technique for preserving neighborhood relationships.
# 4. **Isomap:**
#    - Captures global structure by geodesic distances.
#
# ---
#
# ### **Advantages of Using `map-learn`:**
# - Simplifies complex manifold-learning algorithms.
# - Supports integration with Scikit-learn tools and pipelines.
# - Provides high-quality visualizations for exploratory data analysis.

# %%
#Import statements 
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn.datasets import fetch_openml

# figure size in inches
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

import umap

sns.set_theme()
plt.rcParams['figure.figsize'] = [10, 8]
# Out:
# /opt/anaconda3/envs/venvum/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:14: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.sparse import csr_matrix, issparse

# %% [markdown]
# Umap Embedding of iris dataset

# %%
# Load the data
iris = load_iris()

iris_data = iris['data']
iris_label = iris['target_names'][iris['target']]

# Scale iris data
scaled_iris_data = StandardScaler().fit_transform(iris_data)

# Transform the data
umap_obj = umap.UMAP(n_neighbors=20)
umap_obj = umap_obj.fit(scaled_iris_data)
embedding = umap_obj.transform(scaled_iris_data)

# Plot embeded data
embedding_df = pd.DataFrame(embedding, columns=['UMAP1', 'UMAP2'])
embedding_df['label'] = iris_label

sns.scatterplot(embedding_df, x='UMAP1', y='UMAP2', hue='label')
# Out:
# /opt/anaconda3/envs/venvum/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/anaconda3/envs/venvum/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# <Axes: xlabel='UMAP1', ylabel='UMAP2'>

# %%
scaled_iris_data
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
embedding_df
# Out:
#         UMAP1     UMAP2      label
# 0    7.656030  3.490740     setosa
# 1    9.784509  4.553397     setosa
# 2    9.262694  4.800340     setosa
# 3    9.489005  4.952919     setosa
# 4    7.440813  3.174662     setosa
# ..        ...       ...        ...
# 145 -6.738563  4.442001  virginica
# 146 -4.915549  2.429353  virginica
# 147 -6.510188  4.110363  virginica
# 148 -6.147364  5.114080  virginica
# 149 -5.910651  2.676566  virginica
#
# [150 rows x 3 columns]

# %%
iris_data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
umap_obj.embedding_
# Out:
# array([[ 7.6560297 ,  3.49074   ],
#        [ 9.784509  ,  4.5533967 ],
#        [ 9.262694  ,  4.80034   ],
#        [ 9.489005  ,  4.952919  ],
#        [ 7.4408126 ,  3.1746616 ],
#        [ 6.7965083 ,  2.7359686 ],
#        [ 8.413523  ,  3.816438  ],
#        [ 8.145228  ,  3.7604835 ],
#        [ 9.782776  ,  4.9581637 ],
#        [ 9.446798  ,  4.423351  ],
#        [ 7.0266643 ,  2.9282994 ],
#        [ 8.284474  ,  3.7268994 ],
#        [ 9.770675  ,  4.6656647 ],
#        [ 9.770659  ,  5.01923   ],
#        [ 6.491455  ,  2.6005433 ],
#        [ 6.4228234 ,  2.515333  ],
#        [ 6.7113624 ,  2.5206678 ],
#        [ 7.7393837 ,  3.3995392 ],
#        [ 6.6262054 ,  2.8025138 ],
#        [ 7.251761  ,  2.5600474 ],
#        [ 7.321576  ,  3.8104897 ],
#        [ 7.209307  ,  2.8093448 ],
#        [ 7.982301  ,  3.2490366 ],
#        [ 8.036641  ,  4.0482593 ],
#        [ 8.323059  ,  3.8333473 ],
#        [ 9.841866  ,  4.4952636 ],
#        [ 7.935284  ,  3.8808436 ],
# ...

# %%
umap_obj.graph_
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 3594 stored elements and shape (150, 150)>

# %% [markdown]
# Umap embedding of digits datasets

# %%
# Load the digits data
mnist = fetch_openml('mnist_784', parser='auto')

# Normalize digits data
mnist_data = mnist.data/255
mnist_label = mnist.target

n_row = 10
n_col = 10
fig, axes = plt.subplots(n_row, n_col, figsize=(10, 10))

mnist_data_np = mnist_data.to_numpy()
mnist_labels_np = mnist_label.to_numpy()

# Loop through subplots to populate them with MNIST digits
for i in range(n_row):
    # Get indices of digits that match the current row number (i.e., '0' for the first row, '1' for the second, etc.)
    indices = np.where(mnist_labels_np == str(i))[0][:n_col]  # Take first 'n_col' indices

    for j in range(n_col):
        
        ax = axes[i, j]  # Get the subplot

        # Reshape the 784-number array back to a 28x28 image and plot it
        ax.imshow(mnist_data_np[indices[j]].reshape(28, 28), cmap='gray')

        # Hide axis labels and ticks
        ax.axis('off')

# Show the grid of MNIST digits
plt.show()

# %%
# Perfrom UMAP dimensionality reduction
umap_obj = umap.UMAP()
embedding = umap_obj.fit_transform(mnist_data)

# Plot embeddings
embedding_df = pd.DataFrame(embedding, columns=['UMAP1', 'UMAP2'])
embedding_df['label'] = mnist_label

sns.scatterplot(embedding_df, x='UMAP1', y='UMAP2', hue='label', alpha=0.6, s=3)
plt.title('UMAP - digits dataset')
plt.show()
# Out:
# /opt/anaconda3/envs/venvum/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
import umap.plot as uplot
# Out:
# /opt/anaconda3/envs/venvum/lib/python3.10/site-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
#   warnings.warn(msg, errors.NumbaWarning)
# /opt/anaconda3/envs/venvum/lib/python3.10/site-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
#   warnings.warn(msg, errors.NumbaWarning)
# /opt/anaconda3/envs/venvum/lib/python3.10/site-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
# ...

# %%
import umap.plot

# %%
print(np.__version__)
# Out:
# 1.23.0

# %%
# Plot with visible densities and labels
uplot.points(umap_obj, labels=mnist_label)
# Out:
# <Axes: >

# %%
uplot.connectivity(umap_obj, show_points=True, labels=mnist_label)
# Out:
# <Axes: >
